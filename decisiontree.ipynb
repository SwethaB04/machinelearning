# %% [markdown]
# <a href="https://colab.research.google.com/github/SwethaB04/machinelearning/blob/main/decisiontree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('bankstock.csv')

# %%
data.head()
# Out:
#          Date    Open    High     Low   Close    Adj Close     Volume
# 0  2014-02-03  1980.0  2000.0  1965.0  1965.0  1691.382568   55407000
# 1  2014-02-04  1970.0  1980.0  1940.0  1970.0  1695.686035   83683500
# 2  2014-02-05  1980.0  1990.0  1965.0  1990.0  1712.901367   42715000
# 3  2014-02-06  1975.0  2030.0  1970.0  2030.0  1747.331299   63581000
# 4  2014-02-07  2050.0  2060.0  2035.0  2050.0  1764.546753  104825500

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2483.000000  2483.000000  2483.000000  2483.000000  2483.000000
# mean   5219.973822  5265.847765  5173.628675  5219.887233  4886.148684
# std    2223.156537  2240.113146  2206.459905  2223.903144  2276.934419
# min    1970.000000  1980.000000  1940.000000  1965.000000  1691.382568
# 25%    2955.000000  2985.000000  2930.000000  2950.000000  2612.564454
# 50%    5170.000000  5235.000000  5120.000000  5180.000000  4736.543945
# 75%    6822.500000  6890.000000  6740.000000  6800.000000  6349.964111
# max    9775.000000  9775.000000  9675.000000  9750.000000  9750.000000
#
#              Volume
# count  2.483000e+03
# mean   7.997496e+07
# std    5.378122e+07
# min    0.000000e+00
# 25%    5.153575e+07
# 50%    7.009800e+07
# 75%    9.651755e+07
# max    1.062862e+09

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483 entries, 0 to 2482
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2483 non-null   object
#  1   Open       2483 non-null   float64
#  2   High       2483 non-null   float64
#  3   Low        2483 non-null   float64
#  4   Close      2483 non-null   float64
#  5   Adj Close  2483 non-null   float64
#  6   Volume     2483 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 135.9+ KB

# %%
data['Date'] = pd.to_datetime(data['Date']).astype(int)/10**9

# %%
X = data.drop(['Date','Close'], axis=1)
y = data['Close']

# %%
models = 10
rows = 50

# %%
model_para = []
model_accuracy = []
model_metric = []

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
for i in range(models):
    # Select a random subset of rows from the data with replacement
    random_rows = np.random.choice(len(X), rows, replace=True)
    X_train, X_test, y_train, y_test = train_test_split(X.iloc[random_rows], y.iloc[random_rows], test_size=0.2, random_state=i)

    # Train the decision tree model
    model = DecisionTreeRegressor(random_state=i)
    model.fit(X_train, y_train)

    # Make predictions on the test set
    y_pred = model.predict(X_test)

    # Calculate the accuracy and evaluation metrics
    accuracy = r2_score(y_test, y_pred)
    mse = mean_squared_error(y_test, y_pred)

    # Save the model parameters, accuracy, and evaluation metrics
    model_para.append(model.get_params())
    model_accuracy.append(accuracy)
    model_metric.append({'MSE': mse})

    # Print the output of the current decision tree model
    print(f'Model {i+1}:')
    print(f'Accuracy: {accuracy}')
    print(f'MSE: {mse}')
    print('-----------------------')
# Out:
# Model 1:
# Accuracy: 0.9936848319636351
# MSE: 32802.5
# -----------------------
# Model 2:
# Accuracy: 0.9800146670823663
# MSE: 90640.0
# -----------------------
# Model 3:
# Accuracy: 0.9960262734544516
# MSE: 12805.0
# -----------------------
# Model 4:
# Accuracy: 0.9933887663950698
# MSE: 28890.0
# -----------------------
# Model 5:
# Accuracy: 0.9950289660843846
# MSE: 14217.5
# -----------------------
# Model 6:
# Accuracy: 0.9885744061693827
# MSE: 45662.5
# -----------------------
# Model 7:
# Accuracy: 0.998141827699722
# MSE: 7702.5
# -----------------------
# Model 8:
# Accuracy: 0.9929248944773709
# MSE: 34485.0
# -----------------------
# Model 9:
# Accuracy: 0.9907929085223591
# MSE: 25560.0
# -----------------------
# Model 10:
# Accuracy: 0.9931293230852745
# MSE: 24915.0
# -----------------------
